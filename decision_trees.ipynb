# %% [markdown]
# In this notebook I demonstrate the usage of decision trees, random forests and xgboost. There are few concepts to be cited before:
#
# - Entropy: it measures of impurity of a node in a tree
#
# $$S(p_1) = -p_1 \log_2{p_1} - (1 - p_1)\log_2{(1 - p_1)}$$
#
# where $p_1$ is the fraction of true positives in the node.
#
# - Information gain: it measures the purity was accomplished after splitting a node
#
# $$IG = S(p_1^\text{root}) - w^\text{left} S(p_1^\text{left}) - w^\text{right} S(p_1^\text{right})$$
# where $w$ refers to fraction of number of sample in a node with respect to whole dataset
#
# - One hot encode: for multiple output features, e.g. a feature color with outputs red, blue or green, we transform each output in a binary one, i.e. red and non-red as 0 or 1 and so on
#
# - Sampling with replacement: in order to use tree ensembles, we sample a subset of the dataset and replace it into the dataset, in other words, we include the sampled data in a new raffle

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import sqlite3
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split, GridSearchCV

STATE = 60

# %% [markdown]
# To understand these concepts we will use the Credit Score dataset, available in [kaggle](https://www.kaggle.com/datasets/parisrohan/credit-score-classification), in order to classify clients.

# %%
connection = sqlite3.connect('data/Credit.db')
cursor = connection.cursor()

# %% [markdown]
# Cleaning and exploring the data:

# %%
score = cursor.execute("SELECT DISTINCT Credit_Score FROM credit").fetchall()
print(score)
# Out:
# [('Good',), ('Standard',), ('Poor',)]

# %%
n_customers = cursor.execute("SELECT DISTINCT Customer_ID FROM credit WHERE Age > 0 AND Annual_Income != 'NaN' AND Payment_Behaviour != '!@9#%8'").fetchall()
print(len(n_customers))
# Out:
# 12500

# %%
p_behaviour = cursor.execute("SELECT DISTINCT Payment_Behaviour AS pb FROM credit WHERE pb != '!@9#%8'").fetchall()
print(p_behaviour)
# Out:
# [('High_spent_Small_value_payments',), ('Low_spent_Large_value_payments',), ('Low_spent_Medium_value_payments',), ('Low_spent_Small_value_payments',), ('High_spent_Medium_value_payments',), ('High_spent_Large_value_payments',)]

# %%
data_sql = cursor.execute("""
SELECT CAST(Age AS DECIMAL), Num_Credit_Card, Num_Bank_Accounts, Interest_Rate, Num_of_Loan, Num_of_Delayed_Payment, Delay_from_due_date, Num_Credit_Inquiries, Annual_Income, Outstanding_Debt, Credit_Utilization_Ratio, Changed_Credit_Limit, Amount_invested_monthly, Payment_Behaviour, Credit_Score
FROM (SELECT ID, Customer_ID, Age, Annual_Income, Num_Credit_Card, Num_Bank_Accounts, Interest_Rate, Num_of_Loan, Num_of_Delayed_Payment, Delay_from_due_date, Num_Credit_Inquiries, Outstanding_Debt, Credit_Utilization_Ratio, Changed_Credit_Limit, Amount_invested_monthly, Payment_Behaviour, Credit_Score,
    ROW_NUMBER() OVER (PARTITION BY Customer_ID ORDER BY ID) AS RowNumber
    FROM credit) AS a
WHERE a.RowNumber = 1
AND Payment_Behaviour != '!@9#%8'
AND CAST(Age AS DECIMAL) < 101
AND CAST(Age AS DECIMAL) > 0
AND Num_Credit_Inquiries != 'NA'
AND Num_of_Loan >= 0
""").fetchall()
data_sql = np.array(data_sql)

# %%
cols = ['Age', 'Num_Credit_Card', 'Num_Bank_Accounts', 'Interest_Rate', 'Num_of_Loan', 'Num_of_Delayed_Payment', 'Delay_from_due_date', 'Num_Credit_Inquiries', 'Annual_Income', 'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Changed_Credit_Limit', 'Amount_invested_monthly', 'Payment_Behaviour', 'Credit_Score']
data_pd = pd.DataFrame(data_sql, columns=cols)
data_pd.head()
# Out:
#   Age Num_Credit_Card Num_Bank_Accounts Interest_Rate Num_of_Loan  \
# 0  17               5                 6            27           2
# 1  25               5                 6            17           4
# 2  18               4                 1             1           0
# 3  43               3                 3            17           3
# 4  43               3                 3             6           3
#
#   Num_of_Delayed_Payment Delay_from_due_date Num_Credit_Inquiries  \
# 0                     25                  62                 10.0
# 1                   1749                   8                  2.0
# 2                      7                  14                  1.0
# 3                     12                  27                  7.0
# 4                      9                  12                  3.0
#
#         Annual_Income Outstanding_Debt Credit_Utilization_Ratio  \
# 0            30625.94          1562.91                26.612093
# 1            52312.68           202.68                23.679534
# 2  113781.38999999998           1030.2                 37.99876
# 3            58918.47           473.14                27.513599
# 4            98620.98          1233.51                41.920614
#
#   Changed_Credit_Limit Amount_invested_monthly  \
# 0                 1.63      244.75028300769162
# 1                 9.73       261.2109793689318
# 2                11.34      397.24184577026637
# 3                14.42       74.56738634988751
# 4                 1.33       258.6945882722829
#
#                   Payment_Behaviour Credit_Score
# 0    Low_spent_Large_value_payments     Standard
# 1   Low_spent_Medium_value_payments     Standard
# 2   Low_spent_Medium_value_payments         Poor
# 3   High_spent_Large_value_payments     Standard
# 4  High_spent_Medium_value_payments     Standard

# %%
data_pd_ = data_pd[cols[:-2]].replace('_','', regex=True)
data_pd_1 = data_pd_[cols[:-2]].apply(pd.to_numeric)
data_pd_2 = data_pd[cols[-2:]]
data_pd_temp = data_pd_1.join(data_pd_2)
data_pd_clean = data_pd_temp.dropna()

# %%
X_data_pd = data_pd_clean[cols[:-1]]
y_data_pd = data_pd_clean[cols[-1]]

# %%
X_data_pd = X_data_pd.astype({'Num_Credit_Inquiries':np.int16})

# %% [markdown]
# Making one hot encoding for *Payment_Behaviour*:

# %%
X_data_pd = pd.get_dummies(X_data_pd, 'Payment_Behaviour', 'Payment_Behaviour')
X_data_pd.head(5)
# Out:
#    Age  Num_Credit_Card  Num_Bank_Accounts  Interest_Rate  Num_of_Loan  \
# 0   17                5                  6             27            2
# 1   25                5                  6             17            4
# 2   18                4                  1              1            0
# 3   43                3                  3             17            3
# 4   43                3                  3              6            3
#
#    Num_of_Delayed_Payment  Delay_from_due_date  Num_Credit_Inquiries  \
# 0                    25.0                   62                    10
# 1                  1749.0                    8                     2
# 2                     7.0                   14                     1
# 3                    12.0                   27                     7
# 4                     9.0                   12                     3
#
#    Annual_Income  Outstanding_Debt  Credit_Utilization_Ratio  \
# 0       30625.94           1562.91                 26.612093
# 1       52312.68            202.68                 23.679534
# 2      113781.39           1030.20                 37.998760
# 3       58918.47            473.14                 27.513599
# 4       98620.98           1233.51                 41.920614
#
#    Changed_Credit_Limit  Amount_invested_monthly  \
# 0                  1.63               244.750283
# 1                  9.73               261.210979
# 2                 11.34               397.241846
# 3                 14.42                74.567386
# 4                  1.33               258.694588
#
#    Payment_BehaviourPayment_BehaviourHigh_spent_Large_value_payments  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  1
# 4                                                  0
#
#    Payment_BehaviourPayment_BehaviourHigh_spent_Medium_value_payments  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  1
#
#    Payment_BehaviourPayment_BehaviourHigh_spent_Small_value_payments  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Payment_BehaviourPayment_BehaviourLow_spent_Large_value_payments  \
# 0                                                  1
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Payment_BehaviourPayment_BehaviourLow_spent_Medium_value_payments  \
# 0                                                  0
# 1                                                  1
# 2                                                  1
# 3                                                  0
# 4                                                  0
#
#    Payment_BehaviourPayment_BehaviourLow_spent_Small_value_payments
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0

# %%
X_train, X_cv, y_train, y_cv = train_test_split(X_data_pd, y_data_pd, train_size=0.8, random_state=STATE)

# %%
X_train.head(3)
# Out:
#       Age  Num_Credit_Card  Num_Bank_Accounts  Interest_Rate  Num_of_Loan  \
# 7223   29                3                  4              5            1
# 5232   23                2                  3              7            2
# 3483   37                5                  1              2            0
#
#       Num_of_Delayed_Payment  Delay_from_due_date  Num_Credit_Inquiries  \
# 7223                     6.0                   18                     0
# 5232                     9.0                    9                     4
# 3483                    11.0                   12                     3
#
#       Annual_Income  Outstanding_Debt  Credit_Utilization_Ratio  \
# 7223      163032.60             18.93                 31.310474
# 5232       16653.50            574.43                 39.689331
# 3483       44968.15            871.85                 31.613032
#
#       Changed_Credit_Limit  Amount_invested_monthly  \
# 7223                 15.30              1199.870211
# 5232                 11.50                55.738249
# 3483                  8.22               240.022760
#
#       Payment_BehaviourPayment_BehaviourHigh_spent_Large_value_payments  \
# 7223                                                  0
# 5232                                                  0
# 3483                                                  0
#
#       Payment_BehaviourPayment_BehaviourHigh_spent_Medium_value_payments  \
# 7223                                                  0
# 5232                                                  0
# 3483                                                  0
#
#       Payment_BehaviourPayment_BehaviourHigh_spent_Small_value_payments  \
# 7223                                                  0
# 5232                                                  0
# 3483                                                  1
#
#       Payment_BehaviourPayment_BehaviourLow_spent_Large_value_payments  \
# 7223                                                  1
# 5232                                                  0
# 3483                                                  0
#
#       Payment_BehaviourPayment_BehaviourLow_spent_Medium_value_payments  \
# 7223                                                  0
# 5232                                                  0
# 3483                                                  0
#
#       Payment_BehaviourPayment_BehaviourLow_spent_Small_value_payments
# 7223                                                  0
# 5232                                                  1
# 3483                                                  0

# %%
y_train.head(3)
# Out:
# 7223        Good
# 5232        Good
# 3483    Standard
# Name: Credit_Score, dtype: object

# %%
X_train['Age'].unique()
# Out:
# array([29, 23, 37, 52, 40, 42, 16, 25, 46, 14, 41, 18, 47, 26, 36, 28, 30,
#        39, 34, 49, 44, 19, 51, 32, 55, 45, 24, 38, 31, 21, 50, 33, 48, 27,
#        22, 15, 54, 17, 43, 53, 35, 20, 95], dtype=int64)

# %%
print(len(X_train), len(y_train))
# Out:
# 7400 7400

# %% [markdown]
# #### Decision tree

# %% [markdown]
# Testing a simple decision tree:

# %%
model = DecisionTreeClassifier(random_state=STATE).fit(X_train, y_train)

# %%
pred_train = model.predict(X_train)
pred_cv = model.predict(X_cv)

# %%
accuracy_train = accuracy_score(pred_train, y_train)
accuracy_cv = accuracy_score(pred_cv, y_cv)

print(f'The accuracy over train sample is {accuracy_train*100:.2f}% and over cross-validation is {accuracy_cv*100:.2f}%.')
# Out:
# The accuracy over train sample is 100.00% and over cross-validation is 67.08%.

# %%
min_samples_array = np.geomspace(1,1500,20, dtype=int)
max_depth_array = np.geomspace(2,90,15, dtype=int)

# %%
accuracy_train_array = np.zeros(len(min_samples_array))
accuracy_cv_array = np.zeros(len(min_samples_array))

i = 0
for min_samples in min_samples_array:
    model = DecisionTreeClassifier(min_samples_split=min_samples, random_state=STATE).fit(X_train, y_train)
    pred_train = model.predict(X_train)
    pred_cv = model.predict(X_cv)
    accuracy_train = accuracy_score(pred_train, y_train)
    accuracy_cv = accuracy_score(pred_cv, y_cv)
    accuracy_train_array[i] = accuracy_train
    accuracy_cv_array[i] = accuracy_cv
    i += 1

sb.set()
plt.plot(min_samples_array, accuracy_train_array, label='Train')
plt.plot(min_samples_array, accuracy_cv_array, label='CV')
plt.legend()
plt.xlabel('Minimum samples to split')
plt.ylabel('Accuracy')
plt.show()

# %% [markdown]
# 1000 for minimum samples to split in a node is a candidate to avoid overfitting and to get a reasonable performance.

# %%
accuracy_train_array = np.zeros(len(max_depth_array))
accuracy_cv_array = np.zeros(len(max_depth_array))

i = 0
for max_depth in max_depth_array:
    model = DecisionTreeClassifier(min_samples_split=1000, max_depth=max_depth, random_state=STATE).fit(X_train, y_train)
    pred_train = model.predict(X_train)
    pred_cv = model.predict(X_cv)
    accuracy_train = accuracy_score(pred_train, y_train)
    accuracy_cv = accuracy_score(pred_cv, y_cv)
    accuracy_train_array[i] = accuracy_train
    accuracy_cv_array[i] = accuracy_cv
    i += 1

sb.set()
plt.plot(max_depth_array, accuracy_train_array, label='Train')
plt.plot(max_depth_array, accuracy_cv_array, label='CV')
plt.legend()
plt.xlabel('Maximum depth')
plt.ylabel('Accuracy')
plt.show()

# %%
model = DecisionTreeClassifier(min_samples_split=1000, max_depth=max_depth, random_state=STATE).fit(X_train, y_train)

pred_train = model.predict(X_train)
pred_cv = model.predict(X_cv)

accuracy_train = accuracy_score(pred_train, y_train)
accuracy_cv = accuracy_score(pred_cv, y_cv)

print(accuracy_train, accuracy_cv)
# Out:
# 0.7347297297297297 0.725945945945946

# %% [markdown]
# #### Random Forest

# %%
n_estimatiors_array = np.geomspace(2,1500,30, dtype=int)
max_depth_array = np.geomspace(2,40,15, dtype=int)

# %%
accuracy_train_array = np.zeros(len(min_samples_array))
accuracy_cv_array = np.zeros(len(min_samples_array))

i = 0
for min_samples in min_samples_array:
    model = RandomForestClassifier(min_samples_split=min_samples, random_state=STATE).fit(X_train, y_train)
    pred_train = model.predict(X_train)
    pred_cv = model.predict(X_cv)
    accuracy_train = accuracy_score(pred_train, y_train)
    accuracy_cv = accuracy_score(pred_cv, y_cv)
    accuracy_train_array[i] = accuracy_train
    accuracy_cv_array[i] = accuracy_cv
    i += 1

sb.set()
plt.plot(min_samples_array, accuracy_train_array, label='Train')
plt.plot(min_samples_array, accuracy_cv_array, label='CV')
plt.legend()
plt.xlabel('Minimum samples to split')
plt.ylabel('Accuracy')
plt.show()

# %%
accuracy_train_array = np.zeros(len(max_depth_array))
accuracy_cv_array = np.zeros(len(max_depth_array))

i = 0
for max_depth in max_depth_array:
    model = RandomForestClassifier(min_samples_split=480, max_depth=max_depth, random_state=STATE).fit(X_train, y_train)
    pred_train = model.predict(X_train)
    pred_cv = model.predict(X_cv)
    accuracy_train = accuracy_score(pred_train, y_train)
    accuracy_cv = accuracy_score(pred_cv, y_cv)
    accuracy_train_array[i] = accuracy_train
    accuracy_cv_array[i] = accuracy_cv
    i += 1

sb.set()
plt.plot(max_depth_array, accuracy_train_array, label='Train')
plt.plot(max_depth_array, accuracy_cv_array, label='CV')
plt.legend()
plt.xlabel('Maximum depth')
plt.ylabel('Accuracy')
plt.show()

# %%
accuracy_train_array = np.zeros(len(n_estimatiors_array))
accuracy_cv_array = np.zeros(len(n_estimatiors_array))

i = 0
for n_trees in n_estimatiors_array:
    model = RandomForestClassifier(min_samples_split=480, max_depth=14, n_estimators=n_trees, random_state=STATE).fit(X_train, y_train)
    pred_train = model.predict(X_train)
    pred_cv = model.predict(X_cv)
    accuracy_train = accuracy_score(pred_train, y_train)
    accuracy_cv = accuracy_score(pred_cv, y_cv)
    accuracy_train_array[i] = accuracy_train
    accuracy_cv_array[i] = accuracy_cv
    i += 1

sb.set()
plt.plot(n_estimatiors_array, accuracy_train_array, label='Train')
plt.plot(n_estimatiors_array, accuracy_cv_array, label='CV')
plt.legend()
plt.xlabel('Number of estimators')
plt.ylabel('Accuracy')
plt.show()

# %%
model = RandomForestClassifier(n_estimators=700, max_depth=14, min_samples_split=480).fit(X_train, y_train)

pred_train = model.predict(X_train)
pred_cv = model.predict(X_cv)
accuracy_train = accuracy_score(pred_train, y_train)
accuracy_cv = accuracy_score(pred_cv, y_cv)

print(accuracy_train, accuracy_cv)
# Out:
# 0.7513513513513513 0.7367567567567568

# %% [markdown]
# Testing GridSearchCV:

# %%
model = RandomForestClassifier()

n_estimatiors_array = np.geomspace(2,500,5, dtype=int)
min_samples_array = np.geomspace(1,1500,5, dtype=int)
max_depth_array = np.geomspace(2,90,5, dtype=int)

parameters = {'n_estimators':n_estimatiors_array,
              'max_depth':max_depth_array,
              'min_samples_split':min_samples_array}

grid = GridSearchCV(estimator=model, param_grid=parameters, scoring='accuracy', cv=10, verbose=3)

grid_fit = grid.fit(X_train, y_train)

# %%
grid.best_estimator_
# Out:
# RandomForestClassifier(max_depth=90, min_samples_split=38, n_estimators=125)

# %%
pred_train = grid_fit.predict(X_train)
pred_cv = grid_fit.predict(X_cv)

acc_train = accuracy_score(y_train, pred_train)
acc_cv = accuracy_score(y_cv, pred_cv)

print(f'Accuracy:\nTrain:{acc_train*100:.2f}%\nCV:{acc_cv*100:.2f}%')
# Out:
# Accuracy:
# Train:82.07%
# CV:73.69%

# %%
import joblib

joblib.dump(grid, 'models/credit_score/GridSearchCV_for_credit_score.pkl')
# Out:
# ['models/credit_score/GridSearchCV_for_credit_score.pkl']

# %% [markdown]
# #### XGBoost

# %%
X_train_xg, X_eval, y_train_xg, y_eval = train_test_split(X_train, y_train, train_size=0.8, random_state=STATE)

y_train_xg = y_train_xg.replace('Poor',0)
y_train_xg = y_train_xg.replace('Standard',1)
y_train_xg = y_train_xg.replace('Good',2)

y_eval = y_eval.replace('Poor',0)
y_eval = y_eval.replace('Standard',1)
y_eval = y_eval.replace('Good',2)

y_cv_xg = y_cv.replace('Poor',0)
y_cv_xg = y_cv_xg.replace('Standard',1)
y_cv_xg = y_cv_xg.replace('Good',2)

eval = [(X_eval, y_eval)]

# %%
xgboost_model = XGBClassifier(n_estimators=500, learning_rate=0.1, random_state=STATE, early_stopping_rounds=10)

# %%
xgboost_model.fit(X_train_xg, y_train_xg, eval_set=eval)
# Out:
# [0]	validation_0-mlogloss:1.02706
# [1]	validation_0-mlogloss:0.96705
# [2]	validation_0-mlogloss:0.91556
# [3]	validation_0-mlogloss:0.87073
# [4]	validation_0-mlogloss:0.83220
# [5]	validation_0-mlogloss:0.79921
# [6]	validation_0-mlogloss:0.77000
# [7]	validation_0-mlogloss:0.74473
# [8]	validation_0-mlogloss:0.72213
# [9]	validation_0-mlogloss:0.70223
# [10]	validation_0-mlogloss:0.68423
# [11]	validation_0-mlogloss:0.66849
# [12]	validation_0-mlogloss:0.65424
# [13]	validation_0-mlogloss:0.64164
# [14]	validation_0-mlogloss:0.63004
# [15]	validation_0-mlogloss:0.61971
# [16]	validation_0-mlogloss:0.61096
# [17]	validation_0-mlogloss:0.60295
# [18]	validation_0-mlogloss:0.59595
# [19]	validation_0-mlogloss:0.58975
# [20]	validation_0-mlogloss:0.58430
# [21]	validation_0-mlogloss:0.57884
# [22]	validation_0-mlogloss:0.57471
# [23]	validation_0-mlogloss:0.57075
# [24]	validation_0-mlogloss:0.56658
# [25]	validation_0-mlogloss:0.56326
# [26]	validation_0-mlogloss:0.56001
# [27]	validation_0-mlogloss:0.55728
# [28]	validation_0-mlogloss:0.55525
# [29]	validation_0-mlogloss:0.55300
# [30]	validation_0-mlogloss:0.55117
# [31]	validation_0-mlogloss:0.54926
# [32]	validation_0-mlogloss:0.54743
# [33]	validation_0-mlogloss:0.54602
# [34]	validation_0-mlogloss:0.54445
# [35]	validation_0-mlogloss:0.54363
# [36]	validation_0-mlogloss:0.54297
# [37]	validation_0-mlogloss:0.54214
# [38]	validation_0-mlogloss:0.54190
# [39]	validation_0-mlogloss:0.54134
# [40]	validation_0-mlogloss:0.54037
# [41]	validation_0-mlogloss:0.53945
# [42]	validation_0-mlogloss:0.53885
# [43]	validation_0-mlogloss:0.53828
# [44]	validation_0-mlogloss:0.53777
# [45]	validation_0-mlogloss:0.53697
# [46]	validation_0-mlogloss:0.53628
# [47]	validation_0-mlogloss:0.53581
# [48]	validation_0-mlogloss:0.53515
# [49]	validation_0-mlogloss:0.53478
# [50]	validation_0-mlogloss:0.53444
# [51]	validation_0-mlogloss:0.53422
# [52]	validation_0-mlogloss:0.53414
# [53]	validation_0-mlogloss:0.53401
# [54]	validation_0-mlogloss:0.53365
# [55]	validation_0-mlogloss:0.53353
# [56]	validation_0-mlogloss:0.53349
# [57]	validation_0-mlogloss:0.53353
# [58]	validation_0-mlogloss:0.53353
# [59]	validation_0-mlogloss:0.53356
# [60]	validation_0-mlogloss:0.53329
# [61]	validation_0-mlogloss:0.53318
# [62]	validation_0-mlogloss:0.53293
# [63]	validation_0-mlogloss:0.53298
# [64]	validation_0-mlogloss:0.53293
# [65]	validation_0-mlogloss:0.53282
# [66]	validation_0-mlogloss:0.53244
# [67]	validation_0-mlogloss:0.53242
# [68]	validation_0-mlogloss:0.53237
# [69]	validation_0-mlogloss:0.53260
# [70]	validation_0-mlogloss:0.53258
# [71]	validation_0-mlogloss:0.53257
# [72]	validation_0-mlogloss:0.53267
# [73]	validation_0-mlogloss:0.53261
# [74]	validation_0-mlogloss:0.53290
# [75]	validation_0-mlogloss:0.53304
# [76]	validation_0-mlogloss:0.53296
# [77]	validation_0-mlogloss:0.53304
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=500, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)

# %%
bas = xgboost_model.base_score
bi = xgboost_model.best_iteration
bnl = xgboost_model.best_ntree_limit
bes = xgboost_model.best_score

print(bas,bi,bnl,bes)
# Out:
# None 68 69 0.5323652603937238

# %%
pred_train_xg = xgboost_model.predict(X_train_xg)
pred_eval = xgboost_model.predict(X_eval)
pred_cv = xgboost_model.predict(X_cv)

acc_train = accuracy_score(y_train_xg, pred_train_xg)
acc_eval = accuracy_score(y_eval, pred_eval)
acc_cv = accuracy_score(y_cv_xg, pred_cv)

print(f'The accuracy obtained in train and cross validation:\n Train: {acc_train}\n Eval: {acc_eval}\n CV: {acc_cv}')
# Out:
# The accuracy obtained in train and cross validation:
#  Train: 0.8628378378378379
#  Eval: 0.7587837837837837
#  CV: 0.7475675675675676

# %% [markdown]
# Comparing to neural networks:

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import L2

# %%
X_train_np = X_train.to_numpy(dtype=np.float32)
y_train_np = y_train.to_numpy()
X_cv_np = X_cv.to_numpy(dtype=np.float32)
y_cv_np = y_cv.to_numpy()

y_train_np[y_train_np == 'Good'] = 2
y_train_np[y_train_np == 'Standard'] = 1
y_train_np[y_train_np == 'Poor'] = 0
y_train_np = y_train_np.astype('int8')

y_cv_np[y_cv_np == 'Good'] = 2
y_cv_np[y_cv_np == 'Standard'] = 1
y_cv_np[y_cv_np == 'Poor'] = 0
y_cv_np = y_cv_np.astype('int8')

# %%
def create_model(X_, y_, reg_value, n_units):
    shape_init = tf.keras.Input(shape=(len(X_[0]),))
    units_list = []
    m,n = X_.shape

    model = Sequential([shape_init,
                        Dense(units=n_units, activation='relu', kernel_regularizer=L2(reg_value)),
                        Dense(units=3, activation='linear', kernel_regularizer=L2(reg_value))],
                    name='Using_NN_to_classify%i_units'%n_units
                    )
    # model.summary()
    model.compile(loss=SparseCategoricalCrossentropy(from_logits=True), optimizer=Adam(0.01))
    model.fit(X_, y_, epochs=20)
    
    return model

def misclassification(X_, y_, prediction):
    j = 0
    m,n = X_.shape
    for i in range(m):
        ip = np.where(prediction[i] == max(prediction[i]))
        if ip[0][0] != y_[i]:
            j += 1
    J = j/m
    return J

def cost_final(X_, y_, X_cv_, y_cv_, n_units, reg_value):
    model = create_model(X_, y_, reg_value, n_units)
    prediction = model.predict(X_)
    prediction_cv = model.predict(X_cv_)

    J_train = misclassification(X_, y_, prediction)
    J_cv = misclassification(X_cv_, y_cv_, prediction_cv)
    
    return J_train, J_cv, model

def evaluate_units(X_, y_, X_cv_, y_cv_):
    n_units_list = [int(j) for j in range(30,300,30)]
    J_train_array = np.zeros(len(n_units_list))
    J_cv_array = np.zeros(len(n_units_list))
    reg_value = 0.01

    for i in range(len(n_units_list)):
        n_units = n_units_list[i]
        print(n_units, ' units')
        J_train, J_cv, model = cost_final(X_, y_, X_cv_, y_cv_, n_units, reg_value)

        J_train_array[i] = J_train
        J_cv_array[i] = J_cv
        
    return J_train_array, J_cv_array, n_units_list

J_train_array, J_cv_array, n_units_list = evaluate_units(X_train_np, y_train_np, X_cv_np, y_cv_np)
# Out:
# 30  units
# Epoch 1/20
# 232/232 [==============================] - 1s 1ms/step - loss: 10231.4258
# Epoch 2/20
# 232/232 [==============================] - 0s 2ms/step - loss: 8764.7920
# Epoch 3/20
# 232/232 [==============================] - 0s 1ms/step - loss: 4361.5537
# Epoch 4/20
# 232/232 [==============================] - 0s 1ms/step - loss: 3082.7351
# Epoch 5/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1795.1573
# Epoch 6/20
# 232/232 [==============================] - 0s 1ms/step - loss: 379.1870
# Epoch 7/20
# 232/232 [==============================] - 0s 1ms/step - loss: 148.9622
# Epoch 8/20
# 232/232 [==============================] - 0s 2ms/step - loss: 2.0241
# Epoch 9/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.9192
# Epoch 10/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.8535
# Epoch 11/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.7934
# Epoch 12/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.7347
# Epoch 13/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.6759
# Epoch 14/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.6186
# Epoch 15/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.5632
# Epoch 16/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.5099
# Epoch 17/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.4590
# Epoch 18/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.4109
# Epoch 19/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.3654
# Epoch 20/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.3236
# 232/232 [==============================] - 0s 1ms/step
# 58/58 [==============================] - 0s 1ms/step
# 60  units
# Epoch 1/20
# 232/232 [==============================] - 1s 1ms/step - loss: 10576.2393
# Epoch 2/20
# 232/232 [==============================] - 0s 2ms/step - loss: 2054.8225
# Epoch 3/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1160.2710
# Epoch 4/20
# 232/232 [==============================] - 0s 1ms/step - loss: 281.4702
# Epoch 5/20
# 232/232 [==============================] - 0s 1ms/step - loss: 88.2600
# Epoch 6/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.5385
# Epoch 7/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.4570
# Epoch 8/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.4025
# Epoch 9/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.3419
# Epoch 10/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.2746
# Epoch 11/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.2283
# Epoch 12/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.1922
# Epoch 13/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.1472
# Epoch 14/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.1118
# Epoch 15/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.0883
# Epoch 16/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.0611
# Epoch 17/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.0457
# Epoch 18/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.0692
# Epoch 19/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.0835
# Epoch 20/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.0568
# 232/232 [==============================] - 0s 1ms/step
# 58/58 [==============================] - 0s 1ms/step
# 90  units
# Epoch 1/20
# 232/232 [==============================] - 1s 1ms/step - loss: 12974.3447
# Epoch 2/20
# 232/232 [==============================] - 0s 1ms/step - loss: 11247.4150
# Epoch 3/20
# 232/232 [==============================] - 0s 2ms/step - loss: 3128.1926
# Epoch 4/20
# 232/232 [==============================] - 0s 1ms/step - loss: 593.9768
# Epoch 5/20
# 232/232 [==============================] - 0s 1ms/step - loss: 20.8494
# Epoch 6/20
# 232/232 [==============================] - 0s 1ms/step - loss: 2.1718
# Epoch 7/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.9818
# Epoch 8/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.7822
# Epoch 9/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.6300
# Epoch 10/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.5766
# Epoch 11/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.5249
# Epoch 12/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.4205
# Epoch 13/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.3226
# Epoch 14/20
# 232/232 [==============================] - 0s 1ms/step - loss: 1.2587
# Epoch 15/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.2124
# Epoch 16/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.1803
# Epoch 17/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.1469
# Epoch 18/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.1308
# Epoch 19/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0774
# Epoch 20/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0607
# 232/232 [==============================] - 1s 3ms/step
# 58/58 [==============================] - 0s 1ms/step
# 120  units
# Epoch 1/20
# 232/232 [==============================] - 1s 2ms/step - loss: 13255.7715
# Epoch 2/20
# 232/232 [==============================] - 1s 2ms/step - loss: 814.4413
# Epoch 3/20
# 232/232 [==============================] - 1s 2ms/step - loss: 91.8000
# Epoch 4/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.5615
# Epoch 5/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.4399
# Epoch 6/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.3783
# Epoch 7/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.3241
# Epoch 8/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.2927
# Epoch 9/20
# 232/232 [==============================] - 1s 2ms/step - loss: 1.2525
# Epoch 10/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.2321
# Epoch 11/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.2127
# Epoch 12/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.1759
# Epoch 13/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.1558
# Epoch 14/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.1502
# Epoch 15/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.1135
# Epoch 16/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.0963
# Epoch 17/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0821
# Epoch 18/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0506
# Epoch 19/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.0388
# Epoch 20/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0304
# 232/232 [==============================] - 1s 4ms/step
# 58/58 [==============================] - 0s 3ms/step
# 150  units
# Epoch 1/20
# 232/232 [==============================] - 1s 2ms/step - loss: 11448.3965
# Epoch 2/20
# 232/232 [==============================] - 0s 2ms/step - loss: 3799.2090
# Epoch 3/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1181.8038
# Epoch 4/20
# 232/232 [==============================] - 0s 2ms/step - loss: 2.0451
# Epoch 5/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.7077
# Epoch 6/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.6181
# Epoch 7/20
# 232/232 [==============================] - 1s 2ms/step - loss: 1.5409
# Epoch 8/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.4537
# Epoch 9/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.3822
# Epoch 10/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.3282
# Epoch 11/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.2800
# Epoch 12/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.2405
# Epoch 13/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.2043
# Epoch 14/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.1746
# Epoch 15/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.1382
# Epoch 16/20
# 232/232 [==============================] - 0s 2ms/step - loss: 1.1253
# Epoch 17/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0986
# Epoch 18/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0880
# Epoch 19/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0701
# Epoch 20/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.0424
# 232/232 [==============================] - 1s 3ms/step
# 58/58 [==============================] - 0s 3ms/step
# 180  units
# Epoch 1/20
# 232/232 [==============================] - 1s 3ms/step - loss: 12828.8145
# Epoch 2/20
# 232/232 [==============================] - 1s 3ms/step - loss: 869.6330
# Epoch 3/20
# 232/232 [==============================] - 1s 4ms/step - loss: 26.6625
# Epoch 4/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.5358
# Epoch 5/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.4228
# Epoch 6/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.3701
# Epoch 7/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.2853
# Epoch 8/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.2452
# Epoch 9/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.1881
# Epoch 10/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.1551
# Epoch 11/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.2102
# Epoch 12/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.1664
# Epoch 13/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.1177
# Epoch 14/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.0851
# Epoch 15/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0892
# Epoch 16/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0354
# Epoch 17/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.0306
# Epoch 18/20
# 232/232 [==============================] - 1s 5ms/step - loss: 1.0142
# Epoch 19/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.0676
# Epoch 20/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0501
# 232/232 [==============================] - 1s 2ms/step
# 58/58 [==============================] - 0s 2ms/step
# 210  units
# Epoch 1/20
# 232/232 [==============================] - 1s 3ms/step - loss: 11946.3672
# Epoch 2/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1248.6377
# Epoch 3/20
# 232/232 [==============================] - 1s 3ms/step - loss: 288.0676
# Epoch 4/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.9510
# Epoch 5/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.6721
# Epoch 6/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.5745
# Epoch 7/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.4317
# Epoch 8/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.3496
# Epoch 9/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.2871
# Epoch 10/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.2355
# Epoch 11/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.1901
# Epoch 12/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.1709
# Epoch 13/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.1383
# Epoch 14/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.1055
# Epoch 15/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0802
# Epoch 16/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.0626
# Epoch 17/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0440
# Epoch 18/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0148
# Epoch 19/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0101
# Epoch 20/20
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9851
# 232/232 [==============================] - 1s 2ms/step
# 58/58 [==============================] - 0s 2ms/step
# 240  units
# Epoch 1/20
# 232/232 [==============================] - 1s 3ms/step - loss: 7903.3350
# Epoch 2/20
# 232/232 [==============================] - 1s 4ms/step - loss: 245.9261
# Epoch 3/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.5382
# Epoch 4/20
# 232/232 [==============================] - 1s 5ms/step - loss: 1.3335
# Epoch 5/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.2534
# Epoch 6/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.2027
# Epoch 7/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.1687
# Epoch 8/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.1379
# Epoch 9/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.1161
# Epoch 10/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0999
# Epoch 11/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0785
# Epoch 12/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.0653
# Epoch 13/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0549
# Epoch 14/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0453
# Epoch 15/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.0388
# Epoch 16/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0345
# Epoch 17/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0284
# Epoch 18/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0211
# Epoch 19/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.0238
# Epoch 20/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0158
# 232/232 [==============================] - 1s 2ms/step
# 58/58 [==============================] - 0s 2ms/step
# 270  units
# Epoch 1/20
# 232/232 [==============================] - 2s 4ms/step - loss: 10194.2002
# Epoch 2/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1097.7900
# Epoch 3/20
# 232/232 [==============================] - 1s 3ms/step - loss: 20.3038
# Epoch 4/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.5601
# Epoch 5/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.4478
# Epoch 6/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.3581
# Epoch 7/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.2781
# Epoch 8/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.2206
# Epoch 9/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.1755
# Epoch 10/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.1318
# Epoch 11/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.0983
# Epoch 12/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0734
# Epoch 13/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0543
# Epoch 14/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.0370
# Epoch 15/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0210
# Epoch 16/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0462
# Epoch 17/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.0566
# Epoch 18/20
# 232/232 [==============================] - 1s 4ms/step - loss: 1.0188
# Epoch 19/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0192
# Epoch 20/20
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0092
# 232/232 [==============================] - 1s 3ms/step
# 58/58 [==============================] - 0s 2ms/step

# %%
plt.figure(dpi=100)
sb.set()
plt.plot(n_units_list, J_train_array, 'ro-', lw=3, label=r'$J_{train}$')
plt.plot(n_units_list, J_cv_array, 'bo-', lw=3, label=r'$J_{CV}$')
plt.xlabel(r'Number of Layers', fontsize=15)
plt.ylabel(r'$J$', fontsize=15)
plt.legend()
plt.show()

# %%
m,n = X_train.shape

print(f'{n} features')

shape_init = tf.keras.Input(shape=(n,))

model = Sequential([shape_init,
                   Dense(units=200, activation='relu', kernel_regularizer=L2(0.01)),
                   Dense(units=150, activation='relu', kernel_regularizer=L2(0.01)),
                   Dense(units=150, activation='relu', kernel_regularizer=L2(0.01)),
                   Dense(units=15, activation='relu', kernel_regularizer=L2(0.01)),
                   Dense(units=10, activation='relu', kernel_regularizer=L2(0.01)),
                   Dense(units=3, activation='linear', kernel_regularizer=L2(0.01))],
                   name='Using_NN_to_classify')
# Out:
# 19 features

# %%
model.compile(loss=SparseCategoricalCrossentropy(from_logits=True), optimizer=Adam(0.001))

# %%
model.fit(X_train_np, y_train_np, epochs=150)
# Out:
# Epoch 1/150
# 232/232 [==============================] - 1s 3ms/step - loss: 75.5926
# Epoch 2/150
# 232/232 [==============================] - 1s 2ms/step - loss: 2.5468
# Epoch 3/150
# 232/232 [==============================] - 1s 2ms/step - loss: 2.3885
# Epoch 4/150
# 232/232 [==============================] - 1s 3ms/step - loss: 2.2709
# Epoch 5/150
# 232/232 [==============================] - 1s 4ms/step - loss: 2.2088
# Epoch 6/150
# 232/232 [==============================] - 1s 3ms/step - loss: 2.1621
# Epoch 7/150
# 232/232 [==============================] - 1s 3ms/step - loss: 2.1255
# Epoch 8/150
# 232/232 [==============================] - 1s 3ms/step - loss: 2.0958
# Epoch 9/150
# 232/232 [==============================] - 1s 2ms/step - loss: 2.0709
# Epoch 10/150
# 232/232 [==============================] - 1s 3ms/step - loss: 2.0497
# Epoch 11/150
# 232/232 [==============================] - 1s 2ms/step - loss: 2.0312
# Epoch 12/150
# 232/232 [==============================] - 1s 3ms/step - loss: 2.0145
# Epoch 13/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.9994
# Epoch 14/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.9853
# Epoch 15/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.9720
# Epoch 16/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.9591
# Epoch 17/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.9467
# Epoch 18/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.9344
# Epoch 19/150
# 232/232 [==============================] - 1s 2ms/step - loss: 1.9223
# Epoch 20/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.9100
# Epoch 21/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.8977
# Epoch 22/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.8851
# Epoch 23/150
# 232/232 [==============================] - 1s 2ms/step - loss: 1.8723
# Epoch 24/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.8593
# Epoch 25/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.8459
# Epoch 26/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.8320
# Epoch 27/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.8177
# Epoch 28/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.8029
# Epoch 29/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.7877
# Epoch 30/150
# 232/232 [==============================] - 1s 2ms/step - loss: 1.7719
# Epoch 31/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.7555
# Epoch 32/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.7385
# Epoch 33/150
# 232/232 [==============================] - 1s 2ms/step - loss: 1.7209
# Epoch 34/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.7026
# Epoch 35/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.6836
# Epoch 36/150
# 232/232 [==============================] - 1s 2ms/step - loss: 1.6640
# Epoch 37/150
# 232/232 [==============================] - 1s 2ms/step - loss: 1.6437
# Epoch 38/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.6228
# Epoch 39/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.6012
# Epoch 40/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.5790
# Epoch 41/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.5562
# Epoch 42/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.5329
# Epoch 43/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.5091
# Epoch 44/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.4848
# Epoch 45/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.4602
# Epoch 46/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.4353
# Epoch 47/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.4101
# Epoch 48/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.3849
# Epoch 49/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.3595
# Epoch 50/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.3342
# Epoch 51/150
# 232/232 [==============================] - 1s 4ms/step - loss: 1.3784
# Epoch 52/150
# 232/232 [==============================] - 1s 4ms/step - loss: 1.3795
# Epoch 53/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.3610
# Epoch 54/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.3448
# Epoch 55/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.3291
# Epoch 56/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.3137
# Epoch 57/150
# 232/232 [==============================] - 1s 2ms/step - loss: 1.2985
# Epoch 58/150
# 232/232 [==============================] - 1s 2ms/step - loss: 1.2834
# Epoch 59/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.2684
# Epoch 60/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.2536
# Epoch 61/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.2389
# Epoch 62/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.2244
# Epoch 63/150
# 232/232 [==============================] - 1s 2ms/step - loss: 1.2100
# Epoch 64/150
# 232/232 [==============================] - 1s 2ms/step - loss: 1.1959
# Epoch 65/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.1820
# Epoch 66/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.1684
# Epoch 67/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.1551
# Epoch 68/150
# 232/232 [==============================] - 1s 2ms/step - loss: 1.1422
# Epoch 69/150
# 232/232 [==============================] - 1s 2ms/step - loss: 1.1301
# Epoch 70/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.1175
# Epoch 71/150
# 232/232 [==============================] - 1s 4ms/step - loss: 1.1057
# Epoch 72/150
# 232/232 [==============================] - 1s 5ms/step - loss: 1.0943
# Epoch 73/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0834
# Epoch 74/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0730
# Epoch 75/150
# 232/232 [==============================] - 1s 4ms/step - loss: 1.0631
# Epoch 76/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0555
# Epoch 77/150
# 232/232 [==============================] - 1s 2ms/step - loss: 1.0449
# Epoch 78/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0367
# Epoch 79/150
# 232/232 [==============================] - 1s 4ms/step - loss: 1.0291
# Epoch 80/150
# 232/232 [==============================] - 1s 5ms/step - loss: 1.0222
# Epoch 81/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0159
# Epoch 82/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0102
# Epoch 83/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0051
# Epoch 84/150
# 232/232 [==============================] - 1s 3ms/step - loss: 1.0005
# Epoch 85/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9966
# Epoch 86/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9932
# Epoch 87/150
# 232/232 [==============================] - 1s 4ms/step - loss: 0.9903
# Epoch 88/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9878
# Epoch 89/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9858
# Epoch 90/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9841
# Epoch 91/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9827
# Epoch 92/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9816
# Epoch 93/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9808
# Epoch 94/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9800
# Epoch 95/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9795
# Epoch 96/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9791
# Epoch 97/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9787
# Epoch 98/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9784
# Epoch 99/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9782
# Epoch 100/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9781
# Epoch 101/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9779
# Epoch 102/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9778
# Epoch 103/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9777
# Epoch 104/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9776
# Epoch 105/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9775
# Epoch 106/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9775
# Epoch 107/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9776
# Epoch 108/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9775
# Epoch 109/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9775
# Epoch 110/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9774
# Epoch 111/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9774
# Epoch 112/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9775
# Epoch 113/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9774
# Epoch 114/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9774
# Epoch 115/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9774
# Epoch 116/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9774
# Epoch 117/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9774
# Epoch 118/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9774
# Epoch 119/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9774
# Epoch 120/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9774
# Epoch 121/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9774
# Epoch 122/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9775
# Epoch 123/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9774
# Epoch 124/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9774
# Epoch 125/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9774
# Epoch 126/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9774
# Epoch 127/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9774
# Epoch 128/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9774
# Epoch 129/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9774
# Epoch 130/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9774
# Epoch 131/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9774
# Epoch 132/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9774
# Epoch 133/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9774
# Epoch 134/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9774
# Epoch 135/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9774
# Epoch 136/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9774
# Epoch 137/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9774
# Epoch 138/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9774
# Epoch 139/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9774
# Epoch 140/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9774
# Epoch 141/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9774
# Epoch 142/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9774
# Epoch 143/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9774
# Epoch 144/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9774
# Epoch 145/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9774
# Epoch 146/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9774
# Epoch 147/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9775
# Epoch 148/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9774
# Epoch 149/150
# 232/232 [==============================] - 1s 2ms/step - loss: 0.9774
# Epoch 150/150
# 232/232 [==============================] - 1s 3ms/step - loss: 0.9775

# %%
p = model.predict(X_train_np)
ip_list = []
print(p)

for i in range(len(p)):
    ip = np.where(p[i] == max(p[i]))
    ip_list.append(ip[0])

pred_NN = np.array(ip_list)
# Out:
# 232/232 [==============================] - 0s 2ms/step
# [[-0.07169543  0.57026416 -0.7017999 ]
#  [-0.07169543  0.57026416 -0.7017999 ]
#  [-0.07169543  0.57026416 -0.7017999 ]
#  ...
#  [-0.07169543  0.57026416 -0.7017999 ]
#  [-0.07169543  0.57026416 -0.7017999 ]
#  [-0.07169543  0.57026416 -0.7017999 ]]

# %%
pred_NN[:100]

# %%
acc_train = accuracy_score(y_train_np, pred_NN)
print(acc_train)
# Out:
# 0.5514864864864865

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# It is designed here a neural network with 3 layers with 50, 35 and 10 neuron respectively to perform a digit (0 to 9) recognition from mnist dataset.

# %%
(X,y),(X_test,y_test)  = tf.keras.datasets.mnist.load_data('mnist.npz')

# %%
X = X.reshape(-1,X[0].shape[0]*X[0].shape[1])
X_test = X_test.reshape(-1,X_test[0].shape[0]*X_test[0].shape[1])

# %%
fig,ax = plt.subplots(3,3,figsize=(5,5))

m,n = X.shape

k = 0
for i in range(ax.shape[0]):
    for j in range(ax.shape[1]):
        k = np.random.randint(m)
        ax[i,j].set_axis_off()
        x = int(np.sqrt(X[k].shape[0]))
        ax[i,j].imshow(X[k].reshape((x,x)), cmap='inferno')
        ax[i,j].set_title(y[k])
        k += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# **Firstly we use softmax for the output layer to test accuracy:**

# %%
shape_init = tf.keras.Input(shape=(len(X[0]),))

model = Sequential([shape_init,
                    Dense(units=50, activation='relu'),
                    Dense(units=35, activation='relu'),
                    Dense(units=10, activation='softmax')],
                    name='Multi_Class_Classification'
                    )

# %%
model.summary()
# Out:
# Model: "Multi_Class_Classification"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 50)                39250
#
#  dense_4 (Dense)             (None, 35)                1785
#
#  dense_5 (Dense)             (None, 10)                360
#
# =================================================================
# Total params: 41,395
# Trainable params: 41,395
# Non-trainable params: 0
# _________________________________________________________________

# %%
layer1,layer2,layer3 = model.layers

# %%
model.compile(loss=SparseCategoricalCrossentropy(), optimizer=Adam(0.0002))

# %%
model.fit(X,y,epochs=30)
# Out:
# Epoch 1/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 3.8810
# Epoch 2/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.7315
# Epoch 3/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4847
# Epoch 4/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3556
# Epoch 5/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2836
# Epoch 6/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2341
# Epoch 7/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2042
# Epoch 8/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1777
# Epoch 9/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1587
# Epoch 10/30
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1430
# Epoch 11/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1316
# Epoch 12/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1170
# Epoch 13/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1099
# Epoch 14/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1013
# Epoch 15/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0929
# Epoch 16/30
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0885
# Epoch 17/30
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0804
# Epoch 18/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0766
# Epoch 19/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0699
# Epoch 20/30
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0663
# Epoch 21/30
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0653
# Epoch 22/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0602
# Epoch 23/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0565
# Epoch 24/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0536
# Epoch 25/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0490
# Epoch 26/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0510
# Epoch 27/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0450
# Epoch 28/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0433
# Epoch 29/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0426
# Epoch 30/30
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0393

# %%
prediction = model.predict(X_test[:20])

for i in range(len(prediction)):
    ip = np.where(prediction[i] == max(prediction[i]))
    print(f'Prediction: {ip[0][0]}   Actual value: {y_test[i]}')
# Out:
# 1/1 [==============================] - 0s 23ms/step
# Prediction: 7   Actual value: 7
# Prediction: 2   Actual value: 2
# Prediction: 1   Actual value: 1
# Prediction: 0   Actual value: 0
# Prediction: 4   Actual value: 4
# Prediction: 1   Actual value: 1
# Prediction: 4   Actual value: 4
# Prediction: 9   Actual value: 9
# Prediction: 6   Actual value: 5
# Prediction: 9   Actual value: 9
# Prediction: 0   Actual value: 0
# Prediction: 6   Actual value: 6
# Prediction: 9   Actual value: 9
# Prediction: 0   Actual value: 0
# Prediction: 1   Actual value: 1
# Prediction: 5   Actual value: 5
# Prediction: 9   Actual value: 9
# Prediction: 7   Actual value: 7
# Prediction: 3   Actual value: 3
# Prediction: 4   Actual value: 4

# %%
y_pred = model.predict(X_test)
y_pred_th = np.zeros(len(y_pred))

ip_list = []

for i in range(len(y_pred)):
    ip = np.where(y_pred[i] == max(y_pred[i]))
    ip_list.append(ip[0])
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
fig,ax = plt.subplots(6,6,figsize=(10,10))

m,n = X_test.shape

k = 0
for i in range(ax.shape[0]):
    for j in range(ax.shape[1]):
        k = np.random.randint(m)
        ax[i,j].set_axis_off()
        x = int(np.sqrt(X_test[k].shape[0]))
        ax[i,j].imshow(X_test[k].reshape((x,x)), cmap='Oranges')
        ax[i,j].set_title(r'%i, %i'%(y_test[k], ip_list[k]), fontsize=10)

fig.suptitle('Comparing actual to predicted values of a multi-class classification of handwritten digits')
plt.tight_layout()
plt.show()

# %%
ip_array = np.array(ip_list).T[0]

iy_results = np.where(y_test != ip_array)[0]

print('There are %i element(s) with different prediction. The precision is of %.4f%%. Let us plot some of them:'%(len(iy_results), 100-len(iy_results)/len(y_test)*100))

fig,ax = plt.subplots(6,6,figsize=(10,10))

m,n = X_test.shape

k = 0
for i in range(ax.shape[0]):
    for j in range(ax.shape[1]):
        k = np.random.choice(iy_results.shape[0])
        ax[i,j].set_axis_off()
        x = int(np.sqrt(X_test[iy_results[k]].shape[0]))
        ax[i,j].imshow(X_test[iy_results[k]].reshape((x,x)), cmap='Greens')
        ax[i,j].set_title(r'%i, %i'%(y_test[iy_results[k]], ip_list[iy_results[k]]), fontsize=10)

fig.suptitle('Comparing wrongly predicted values of a multi-class classification of handwritten digits')
plt.tight_layout()
plt.show()
# Out:
# There are 410 element(s) with different prediction. The precision is of 95.9000%. Let us plot some of them:

# %% [markdown]
# **Now I use a linear activation function for the output layer instead:**

# %%
(X,y),(X_test,y_test)  = tf.keras.datasets.mnist.load_data('mnist.npz')

# %%
X = X.reshape(-1,X[0].shape[0]*X[0].shape[1])
X_test = X_test.reshape(-1,X_test[0].shape[0]*X_test[0].shape[1])

# %%
shape_init = tf.keras.Input(shape=(len(X[0]),))

model = Sequential([shape_init,
                    Dense(units=50, activation='relu'),
                    Dense(units=35, activation='relu'),
                    Dense(units=10, activation='linear')],
                    name='Multi_Class_Classification_linear_softmax'
                    )

# %%
model.summary()
# Out:
# Model: "Multi_Class_Classification_linear_softmax"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                39250
#
#  dense_1 (Dense)             (None, 35)                1785
#
#  dense_2 (Dense)             (None, 10)                360
#
# =================================================================
# Total params: 41,395
# Trainable params: 41,395
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=SparseCategoricalCrossentropy(from_logits=True), optimizer=Adam(0.0002))

# %%
model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0313
# Epoch 2/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0225
# Epoch 3/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0200
# Epoch 4/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0182
# Epoch 5/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0175
# Epoch 6/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0171
# Epoch 7/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0161
# Epoch 8/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0156
# Epoch 9/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0152
# Epoch 10/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0150
# Epoch 11/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0141
# Epoch 12/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0142
# Epoch 13/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0133
# Epoch 14/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0133
# Epoch 15/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0131
# Epoch 16/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0128
# Epoch 17/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0124
# Epoch 18/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0126
# Epoch 19/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0120
# Epoch 20/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0118
# Epoch 21/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0130
# Epoch 22/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0117
# Epoch 23/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0122
# Epoch 24/100
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0115
# Epoch 25/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0114
# Epoch 26/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0110
# Epoch 27/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0112
# Epoch 28/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0108
# Epoch 29/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0108
# Epoch 30/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0102
# Epoch 31/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0107
# Epoch 32/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0108
# Epoch 33/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0104
# Epoch 34/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0119
# Epoch 35/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0096
# Epoch 36/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0099
# Epoch 37/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0105
# Epoch 38/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0107
# Epoch 39/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0101
# Epoch 40/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0094
# Epoch 41/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0098
# Epoch 42/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0099
# Epoch 43/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0097
# Epoch 44/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0096
# Epoch 45/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0093
# Epoch 46/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0096
# Epoch 47/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0095
# Epoch 48/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0091
# Epoch 49/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0102
# Epoch 50/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0096
# Epoch 51/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0091
# Epoch 52/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0091
# Epoch 53/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0092
# Epoch 54/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0085
# Epoch 55/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0085
# Epoch 56/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0088
# Epoch 57/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0102
# Epoch 58/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0085
# Epoch 59/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0087
# Epoch 60/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0083
# Epoch 61/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0088
# Epoch 62/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0086
# Epoch 63/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0083
# Epoch 64/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0087
# Epoch 65/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0099
# Epoch 66/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0078
# Epoch 67/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0082
# Epoch 68/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0090
# Epoch 69/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0080
# Epoch 70/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0085
# Epoch 71/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0087
# Epoch 72/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0078
# Epoch 73/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0078
# Epoch 74/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0096
# Epoch 75/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0078
# Epoch 76/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0076
# Epoch 77/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0078
# Epoch 78/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0084
# Epoch 79/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0078
# Epoch 80/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0078
# Epoch 81/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0074
# Epoch 82/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0082
# Epoch 83/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0080
# Epoch 84/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0089
# Epoch 85/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0079
# Epoch 86/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0080
# Epoch 87/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0073
# Epoch 88/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0081
# Epoch 89/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0075
# Epoch 90/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0081
# Epoch 91/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0074
# Epoch 92/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0080
# Epoch 93/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0087
# Epoch 94/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0071
# Epoch 95/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0077
# Epoch 96/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0074
# Epoch 97/100
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0071
# Epoch 98/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0080
# Epoch 99/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0077
# Epoch 100/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0069

# %%
prediction = model.predict(X_test[:20])

for i in range(len(prediction)):
    ip = np.where(prediction[i] == max(prediction[i]))
    print(f'Prediction: {ip[0][0]}   Actual value: {y_test[i]}')
# Out:
# 1/1 [==============================] - 0s 107ms/step
# Prediction: 7   Actual value: 7
# Prediction: 2   Actual value: 2
# Prediction: 1   Actual value: 1
# Prediction: 0   Actual value: 0
# Prediction: 4   Actual value: 4
# Prediction: 1   Actual value: 1
# Prediction: 4   Actual value: 4
# Prediction: 9   Actual value: 9
# Prediction: 6   Actual value: 5
# Prediction: 9   Actual value: 9
# Prediction: 0   Actual value: 0
# Prediction: 6   Actual value: 6
# Prediction: 9   Actual value: 9
# Prediction: 0   Actual value: 0
# Prediction: 1   Actual value: 1
# Prediction: 5   Actual value: 5
# Prediction: 9   Actual value: 9
# Prediction: 7   Actual value: 7
# Prediction: 3   Actual value: 3
# Prediction: 4   Actual value: 4

# %%
y_pred = model.predict(X_test)
y_pred_th = np.zeros(len(y_pred))

ip_list = []

for i in range(len(y_pred)):
    ip = np.where(y_pred[i] == max(y_pred[i]))
    ip_list.append(ip[0])
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
fig,ax = plt.subplots(6,6,figsize=(10,10))

m,n = X_test.shape

k = 0
for i in range(ax.shape[0]):
    for j in range(ax.shape[1]):
        k = np.random.randint(m)
        ax[i,j].set_axis_off()
        x = int(np.sqrt(X_test[k].shape[0]))
        ax[i,j].imshow(X_test[k].reshape((x,x)), cmap='plasma')
        ax[i,j].set_title(r'%i, %i'%(y_test[k], ip_list[k]), fontsize=10)

fig.suptitle('Comparing actual to predicted values of a multi-class classification of handwritten digits')
plt.tight_layout()
plt.show()

# %%
ip_array = np.array(ip_list).T[0]

iy_results = np.where(y_test != ip_array)[0]

print('There is(are) %i element(s) with different prediction. The precision is of %.4f%%. Let us plot some of them:'%(len(iy_results), 100-len(iy_results)/len(y_test)*100))

fig,ax = plt.subplots(6,6,figsize=(10,10))

m,n = X_test.shape

k = 0
for i in range(ax.shape[0]):
    for j in range(ax.shape[1]):
        k = np.random.choice(iy_results.shape[0])
        ax[i,j].set_axis_off()
        x = int(np.sqrt(X_test[iy_results[k]].shape[0]))
        ax[i,j].imshow(X_test[iy_results[k]].reshape((x,x)), cmap='Greys')
        ax[i,j].set_title(r'%i, %i'%(y_test[iy_results[k]], ip_list[iy_results[k]]), fontsize=10)

fig.suptitle('Comparing wrongly predicted values of a multi-class classification of handwritten digits')
plt.tight_layout()
plt.show()
# Out:
# There is(are) 397 element(s) with different prediction. The precision is of 96.0300%. Let us plot some of them:
